# %%
# + -> addition

10+30
# Out:
# 40

# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %% [markdown]
# come from right to left i.e first a+b and then the new value will be printed

# %%
# - -> sub

10-3
# Out:
# 7

# %%
# / -> div

10/3
# Out:
# 3.3333333333333335

# %%
# // -> floor division

10//3
# Out:
# 3

# %%
# % -> mod function
# single line calculation

10%3
# Out:
# 1

# %%
# ** -> power
#  5*5*5*5*5

5**5
# Out:
# 3125

# %%
pow(2,5)
# here pow() is the built_in_function where it acts like 2power5
# Out:
# 32

# %%
# *** -> cube

3*3*3
# Out:
# 27

# %%
pow(3,3,5)
# 3power3= 27%5 -> 2
# Out:
# 2

# %%
10>20
# Out:
# False

# %%
10<20
# Out:
# True

# %%
10==1
# comparesion
# Out:
# False

# %%
10 != 9
# != -> not equal
# Out:
# True

# %%
10>6 and 10<7
# Out:
# False

# %%
10<5 or 5>6
# Out:
# False
