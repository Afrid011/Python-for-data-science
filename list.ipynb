# %% [markdown]
# **python_ list**
# -  list is represented with [] and memory allocation will  happen where there is comma
# -  you can pass anything ->> any data type.

# %%
a=[10,12,13,14,15]
print(a)
# Out:
# [10, 12, 13, 14, 15]

# %%
a=[10,15,55,30,45]
print(a[3])
# Out:
# 30

# %%
# slicing
print(a[1:4])
# Out:
# [15, 55, 30]

# %%
# skipping
print(a[::2])
# Out:
# [10, 55, 45]

# %% [markdown]
# **list is mutuable or immutable ->> prove it**
#
#
#
# 1.  try to increase the memeory size
# 2.  try to dcreasethe memory size

# %%
# increase the memorysize
