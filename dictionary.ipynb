# %%
a={'age':[20,24,29],'slry':['10k','12k','15k'],'loc':['hyd','bang','chen']}

print(a)
# Out:
# {'age': [20, 24, 29], 'slry': ['10k', '12k', '15k'], 'loc': ['hyd', 'bang', 'chen']}

# %%
a={'age':[20,24,29],'slry':['10k','12k','15k'],'loc':['hyd','bang','chen']}
# dict prepred data->> pandas

import pandas as pd
df=pd.DataFrame(a)
print(df)
print(a)
# Out:
#    age slry   loc
# 0   20  10k   hyd
# 1   24  12k  bang
# 2   29  15k  chen
# {'age': [20, 24, 29], 'slry': ['10k', '12k', '15k'], 'loc': ['hyd', 'bang', 'chen']}

# %% [markdown]
# -  in the place of values we can pass anything ->> int,float,str,tuple,sets

# %%
a={'age':19,'slry':12000,'loc':'hyd','pincode':[12,22]}
print(a)
# Out:
# {'age': 19, 'slry': 12000, 'loc': 'hyd', 'pincode': [12, 22]}

# %% [markdown]
# -  in the place of keys mutuable types are not allowed

# %%
a={'age':19,'slry':12000,'loc':'hyd','pincode':[12,22]}
print(a)
# Out:
# {'age': 19, 'slry': 12000, 'loc': 'hyd', 'pincode': [12, 22]}

# %%
a={'age':19,'slry':12000,'loc':'hyd',[12,33]:[12,22]}
print(a) #mutuable keys cannot be taken
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-4301fa0a9ba9> in <cell line: 1>()
# ----> 1 a={'age':19,'slry':12000,'loc':'hyd',[12,33]:[12,22]}
#       2 print(a)
#
# TypeError: unhashable type: 'list'

# %%
# lets create a good dictionary and work on it

a={'name':'kishore','age':45,'salary':80000}

print(a)
# Out:
# {'name': 'kishore', 'age': 45, 'salary': 80000}

# %%
# if u want to print the specific vlue pleaseuse keys

print(a["age"])
# Out:
# 45

# %%
# what idf u have two key vlues

a={'name':'kishore','age':45,'salary':80000,'name':'prveen'}

print(a)
# Out:
# {'name': 'prveen', 'age': 45, 'salary': 80000}

# %%
# can we add dta into the empty sheet

fruits={}

fruits['carrot']=100
fruits['banana']=200
fruits['mango']=300

print(fruits)
# Out:
# {'carrot': 100, 'banana': 200, 'mango': 300}

# %%
a={'carrot': 100, 'banana': 200, 'mango': 300}

a['carrot']=500

print(a)
# Out:
# {'carrot': 500, 'banana': 200, 'mango': 300}

# %% [markdown]
# -  dict is mutuble or immutable->> prove it??
#
# addition
#
#
# deletion

# %% [markdown]
# -  since we dont have the index concept->> we can use builtinfunctions and we will do it

# %% [markdown]
# **adding**

# %%
# lets try to increase the memory spcae manually

a={'carrot': 100, 'banana': 200, 'mango': 300}

a['carrot']=500

print(a)
# Out:
# {'carrot': 500, 'banana': 200, 'mango': 300}

# %%
# update->> built_in_function

a={'carrot': 100, 'banana': 200, 'mango': 300}

a.update({'grpes':700,'promogranate':900})

print(a)
# Out:
# {'carrot': 100, 'banana': 200, 'mango': 300, 'grpes': 700, 'promogranate': 900}

# %% [markdown]
# **delete**

# %%
a={'carrot': 100, 'banana': 200, 'mango': 300}

del a['carrot']

print(a)
# Out:
# {'banana': 200, 'mango': 300}

# %%
a={'carrot': 100, 'banana': 200, 'mango': 300}

a.pop('banana')

print(a)
# Out:
# {'carrot': 100, 'mango': 300}

# %% [markdown]
# -  so from above content we understood that dct is mutuable

# %%
#keys

a={'carrot': 100, 'banana': 200, 'mango': 300}

print(a.keys())
# Out:
# dict_keys(['carrot', 'banana', 'mango'])

# %%
# values

a={'carrot': 100, 'banana': 200, 'mango': 300}

print(a.values())
# Out:
# dict_values([100, 200, 300])

# %%
#items

a={'carrot': 100, 'banana': 200, 'mango': 300}

print(a.items())
# Out:
# dict_items([('carrot', 100), ('banana', 200), ('mango', 300)])
