# %% [markdown]
# file handling means ->> we are going to woek with files
# ex : csv,.txt,.json,

# %% [markdown]
# ** there are mainly 3 modes in the handling concept**
#
# -  W -> write mode
# -  r -> read mode
# -  a -> add mode

# %% [markdown]
# ** W -> mode-> ussed to write the data into the file**
#
# -  step 1->  w is used to write the data into the file ->> if th file is not there in the specific location w will create the file and will write the data into trhe file....
#
# -  tep2->> if the file is there in te specific location and if it is empty

# %%
a=open('haruk.txt','w')  # file is creating and it is opening
a.write('hello world')  # writing the data into the file
a.close# the file
# Out:
# <function TextIOWrapper.close()>

# %%
a=open('kiran.txt','w')  # file is creating and it is opening
a.write('hello world')  # writing the data into the file
a.close# the file
# Out:
# <function TextIOWrapper.close()>
