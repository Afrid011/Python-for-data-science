# %% [markdown]
# * print -> variable -> condition *

# %%
print('my age i 27')
# Out:
# my age i 27

# %% [markdown]
# in 4 different ways we can add a string data and a variable inside the print condition

# %% [markdown]
# -  1.comma -> will add variable with string inide the print ->30%

# %%
a=27

print('my age is',a)
# Out:
# my age is 27

# %%
a=30
b=55.55
c='USA'

print('my age is',a,'and im travelling to',c,'with',b,'dollars')
# Out:
# my age is 30 and im travelling to USA with 55.55 dollars

# %% [markdown]
# -  2. uomg + operatr -> with ti technque we can add a string with variable but everything should be string only -> one table space will not be given

# %%
a='27' # taking string

print('my age is'+ a) # one tab space will not be givn
# Out:
# my age is27

# %%
a=27

print('my age is '+ str(a)) # to give pace yab on ending quote
# Out:
# my age is 27

# %%
a=30
b=55.55
c='USA'

print('my age is '+str(a)+'and im travelling to '+str(c)+'with '+str(b)+' dollars')
# Out:
# my age is 30and im travelling to USAwith 55.55 dollars

# %% [markdown]
# -  3.using identifiers
#      int -> %d
#      float -> %f
#      str -> %s
